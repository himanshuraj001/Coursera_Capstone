# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

wikipedia_link='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
wikipedia_page= requests.get(wikipedia_link).text

soup = BeautifulSoup(wikipedia_page,'lxml')

# %%
table = soup.find('table')

Postcode      = []
Borough       = []
Neighbourhood = []



for tr_cell in table.find_all('tr'):
    
    counter = 1
    Postcode_var     = -1
    Borough_var       = -1
    Neighbourhood_var = -1
    
    for td_cell in tr_cell.find_all('td'):
        if counter == 1: 
            Postcode_var = td_cell.text
        if counter == 2: 
            Borough_var = td_cell.text
            tag_a_Borough = td_cell.find('a')
            
        if counter == 3: 
            Neighbourhood_var = str(td_cell.text).strip()
            tag_a_Neighbourhood = td_cell.find('a')
            
        counter +=1
        
    if (Postcode_var == 'Not assigned' or Borough_var == 'Not assigned' or Neighbourhood_var == 'Not assigned'): 
        continue
    try:
        if ((tag_a_Borough is None) or (tag_a_Neighbourhood is None)):
            continue
    except:
        pass
    if(Postcode_var == -1 or Borough_var == -1 or Neighbourhood_var == -1):
        continue
        
    Postcode.append(Postcode_var)
    Borough.append(Borough_var)
    Neighbourhood.append(Neighbourhood_var)

# %%
unique_p = set(Postcode)
print('num of unique Postal codes:', len(unique_p))
Postcode_u      = []
Borough_u       = []
Neighbourhood_u = []
latitute=[]
longitute=[]


for postcode_unique_element in unique_p:
    p_var = ''; b_var = ''; n_var = ''; 
    for postcode_idx, postcode_element in enumerate(Postcode):
        if postcode_unique_element == postcode_element:
            p_var = postcode_element;
            b_var = Borough[postcode_idx]
            if n_var == '': 
                n_var = Neighbourhood[postcode_idx]
            else:
                n_var = n_var + ', ' + Neighbourhood[postcode_idx]
    Postcode_u.append(p_var)
    Borough_u.append(b_var)
    Neighbourhood_u.append(n_var)
    latitute.append(None)
    longitute.append(None)
# Out:
# num of unique Postal codes: 84

# %%
toronto_dict = {'Postcode':Postcode_u, 'Borough':Borough_u, 'Neighbourhood':Neighbourhood_u,'Latitude':latitute,'Longitute':longitute}
df_toronto = pd.DataFrame.from_dict(toronto_dict)
df_toronto
# Out:
#    Postcode           Borough  \
# 0       M9A         Etobicoke
# 1       M4H         East York
# 2       M1B       Scarborough
# 3       M9W         Etobicoke
# 4       M9L        North York
# 5       M4Y  Downtown Toronto
# 6       M9N              York
# 7       M3J        North York
# 8       M2H        North York
# 9       M2J        North York
# 10      M5S  Downtown Toronto
# 11      M1T       Scarborough
# 12      M6L        North York
# 13      M1W       Scarborough
# 14      M3H        North York
# 15      M9C         Etobicoke
# 16      M3K        North York
# 17      M5J  Downtown Toronto
# 18      M5K  Downtown Toronto
# 19      M4N   Central Toronto
# 20      M4T   Central Toronto
# 21      M5T  Downtown Toronto
# 22      M6A        North York
# 23      M4K      East Toronto
# 24      M4L      East Toronto
# 25      M4X  Downtown Toronto
# 26      M5X  Downtown Toronto
# 27      M6S      West Toronto
# 28      M4B         East York
# 29      M2K        North York
# ..      ...               ...
# 54      M9P         Etobicoke
# 55      M4V   Central Toronto
# 56      M4C         East York
# 57      M8X         Etobicoke
# 58      M6R      West Toronto
# 59      M5V  Downtown Toronto
# 60      M3C        North York
# 61      M4A        North York
# 62      M5M        North York
# 63      M1N       Scarborough
# 64      M5B  Downtown Toronto
# 65      M9B         Etobicoke
# 66      M6J      West Toronto
# 67      M8Z         Etobicoke
# 68      M5R   Central Toronto
# 69      M2M        North York
# 70      M4E      East Toronto
# 71      M5P   Central Toronto
# 72      M6B        North York
# 73      M5E  Downtown Toronto
# 74      M8V         Etobicoke
# 75      M1E       Scarborough
# 76      M5C  Downtown Toronto
# 77      M1H       Scarborough
# 78      M8Y         Etobicoke
# 79      M5H  Downtown Toronto
# 80      M1S       Scarborough
# 81      M1P       Scarborough
# 82      M4J         East York
# 83      M4G         East York
#
#                                         Neighbourhood Latitude Longitute
# 0                                    Islington Avenue     None      None
# 1                                    Thorncliffe Park     None      None
# 2                                      Rouge, Malvern     None      None
# 3                                           Northwest     None      None
# 4                                       Humber Summit     None      None
# 5                                Church and Wellesley     None      None
# 6                                              Weston     None      None
# 7                     Northwood Park, York University     None      None
# 8                                   Hillcrest Village     None      None
# 9                                          Henry Farm     None      None
# 10                              University of Toronto     None      None
# 11                                      Tam O'Shanter     None      None
# 12                                    Maple Leaf Park     None      None
# 13                                       Steeles West     None      None
# 14                     Bathurst Manor, Wilson Heights     None      None
# 15                                      Markland Wood     None      None
# 16                                        CFB Toronto     None      None
# 17                     Toronto Islands, Union Station     None      None
# 18           Design Exchange, Toronto Dominion Centre     None      None
# 19                                      Lawrence Park     None      None
# 20                                         Moore Park     None      None
# 21          Chinatown, Grange Park, Kensington Market     None      None
# 22                   Lawrence Heights, Lawrence Manor     None      None
# 23                                          Riverdale     None      None
# 24                                       India Bazaar     None      None
# 25                        Cabbagetown, St. James Town     None      None
# 26             First Canadian Place, Underground city     None      None
# 27                                 Runnymede, Swansea     None      None
# 28                    Woodbine Gardens, Parkview Hill     None      None
# 29                                    Bayview Village     None      None
# ..                                                ...      ...       ...
# 54                                          Westmount     None      None
# 55                   Deer Park, Rathnelly, South Hill     None      None
# 56                                   Woodbine Heights     None      None
# 57                                       The Kingsway     None      None
# 58                             Parkdale, Roncesvalles     None      None
# 59  CN Tower, King and Spadina, Railway Lands, Sou...     None      None
# 60                                    Flemingdon Park     None      None
# 61                                   Victoria Village     None      None
# 62                                       Bedford Park     None      None
# 63                                        Birch Cliff     None      None
# 64                                            Ryerson     None      None
# 65       Islington, Princess Gardens, West Deane Park     None      None
# 66                           Little Portugal, Trinity     None      None
# 67      Mimico NW, The Queensway West, South of Bloor     None      None
# 68                               The Annex, Yorkville     None      None
# 69                            Newtonbrook, Willowdale     None      None
# 70                                        The Beaches     None      None
# 71                                  Forest Hill North     None      None
# 72                                          Glencairn     None      None
# 73                                        Berczy Park     None      None
# 74                                        New Toronto     None      None
# 75                             Morningside, West Hill     None      None
# 76                                     St. James Town     None      None
# 77                                          Cedarbrae     None      None
# 78  Humber Bay, King's Mill Park, Mimico NE, Old M...     None      None
# 79                                     Adelaide, King     None      None
# 80                                          Agincourt     None      None
# 81  Dorset Park, Scarborough Town Centre, Wexford ...     None      None
# 82                                       East Toronto     None      None
# 83                                            Leaside     None      None
#
# [84 rows x 5 columns]

# %%
df=pd.read_csv("Geospatial_Coordinates.csv")

# %%
# Out:
# 'Northwest'

# %%
df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
t=0
for i in (df_toronto["Postcode"]):
    f=0
    for j in (df["Postal Code"]):
        if(str(i)==str(j)):
            df_toronto.iloc[t]["Latitude"]= df[f].iloc["Latitude"]
            df_toronto.iloc[t]["Longitude"]= df.iloc[f]["Longitude"]
        f=f+1
    t=t+1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2655             try:
# -> 2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 93
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-ad6af8d8c543> in <module>
#       4     for j in (df["Postal Code"]):
#       5         if(str(i)==str(j)):
# ----> 6             df_toronto.iloc[t]["Latitude"]= df[f].iloc["Latitude"]
#       7             df_toronto.iloc[t]["Longitude"]= df.iloc[f]["Longitude"]
#       8         f=f+1
#
# ~/conda/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
# -> 2658                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2659         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2660         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 93
